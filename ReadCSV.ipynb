# %% [markdown]
# <a href="https://colab.research.google.com/github/Blandskron/ReadCSV/blob/main/ReadCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/csv/paisesgmt.csv')
df
# Out:
#               Nombre Iso2 Iso3 Gmt-utc
# 0         Afganistán   AF  AFG      +4
# 1            Albania   AL  ALB      +1
# 2           Alemania   DE  DEU      +2
# 3            Algeria   DZ  DZA      +1
# 4            Andorra   AD  AND      +2
# ..               ...  ...  ...     ...
# 241  Wallis y Futuna   WF  WLF     +12
# 242            Yemen   YE  YEM      +3
# 243           Yibuti   DJ  DJI      +3
# 244           Zambia   ZM  ZMB      +2
# 245         Zimbabue   ZW  ZWE      +2
#
# [246 rows x 4 columns]

# %%
df_11 = df.loc[df["Gmt-utc"] == +4]
print(df_11)
# Out:
# Empty DataFrame
# Columns: [Nombre, Iso2, Iso3, Gmt-utc]
# Index: []
